# %%
# Test imports one by one to find the culprit
print("Testing numpy...")
import numpy as np
print("✓ numpy works")

print("Testing pandas...")
import pandas as pd
print("✓ pandas works")

print("Testing matplotlib...")
import matplotlib.pyplot as plt
print("✓ matplotlib works")

print("Testing yfinance...")
import yfinance as yf
print("✓ yfinance works")

print("Testing seaborn...")
import seaborn as sns
print("✓ seaborn works")

print("Testing quantstats...")
import quantstats as qs
print("✓ quantstats works")

print("Testing pypfopt...")
import pypfopt as ppo
print("✓ pypfopt works")

print("Testing stable_baselines3...")
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import A2C, PPO, DDPG, SAC, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
print("✓ stable_baselines3 works")

print("Testing torch...")
import torch as th
print("✓ torch works")

print("Testing typing...")
from typing import Tuple
from stable_baselines3.common.policies import BasePolicy
print("✓ All imports successful!")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import utils
import models
import portfolio_env
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Data Loading & Preprocessing

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# # Benchmark Model

# %% [markdown]
# ## Buy and Hold

# %% [markdown]
# ## Mean-Variance Optimization

# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# ## A2C

# %% [markdown]
# ### A2C - Training

# %% [markdown]
# ### A2C - Testing

# %% [markdown]
# ## PPO

# %% [markdown]
# ### PPO - Training

# %% [markdown]
# ### PPO - Testing

# %% [markdown]
# ## DDPG

# %% [markdown]
# ### DDPG - Training

# %% [markdown]
# ### DDPG - Testing

# %% [markdown]
# ## SAC

# %% [markdown]
# ### SAC - Training

# %% [markdown]
# ### SAC - Testing
